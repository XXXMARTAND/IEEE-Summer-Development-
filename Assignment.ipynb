# %% [markdown]
# <a href="https://colab.research.google.com/github/XXXMARTAND/IEEE-Summer-Development-/blob/master/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url='https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/d546eaee765268bf2f487608c537c05e22e4b221/iris.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df1=df.copy()
s_df=df1.loc[df['species']=='setosa']
s_df
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
df2=df.copy()
df2['sepal_length'].mean()
# Out:
# 5.843333333333335

# %%
df3=df.copy()
df3.loc[df3['petal_width']==1.4, 'petal_width']=df3['petal_width']*2
df3
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
df4=df.copy()
n=df4.groupby(['species'] )['petal_length'].transform(max)== df['petal_length']
df[n]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 24            4.8          3.4           1.9          0.2      setosa
# 44            5.1          3.8           1.9          0.4      setosa
# 83            6.0          2.7           5.1          1.6  versicolor
# 118           7.7          2.6           6.9          2.3   virginica

# %%
df5=df.copy()
def fun(num):
  num=num*10
  sum=0
  sum=(num/10)+(num%10)
  return int(sum)
df5['sepal_length'].apply(fun)
# Out:
# 0       6
# 1      13
# 2      11
# 3      10
# 4       5
# 5       9
# 6      10
# 7       5
# 8       8
# 9      13
# 10      9
# 11     12
# 12     12
# 13      7
# 14     13
# 15     12
# 16      9
# 17      6
# 18     12
# 19      6
# 20      9
# 21      6
# 22     10
# 23      6
# 24     12
# 25      5
# 26      5
# 27      7
# 28      7
# 29     11
#        ..
# 120    15
# 121    11
# 122    14
# 123     9
# 124    13
# 125     9
# 126     8
# 127     7
# 128    10
# 129     9
# 130    11
# 131    16
# 132    10
# 133     9
# 134     7
# 135    14
# 136     9
# 137    10
# 138     6
# 139    15
# 140    13
# 141    15
# 142    13
# 143    14
# 144    13
# 145    13
# 146     9
# 147    11
# 148     8
# 149    14
# Name: sepal_length, Length: 150, dtype: int64

# %%
df6=df.copy()

  
  
  

ma=df6.groupby(['species'])['sepal_width'].max()
mi=df6.groupby(['species'])['sepal_width'].min()
v=ma-mi

v=v.max()
v
df6.loc[0,'species']
# Out:
# 'setosa'

# %%
df7=df.copy()
df7=df7[df7['species']=='versicolor']
average=df7['sepal_length'].mean()

df8=df.copy()
df8=df8[df8['species']=='virginica']
df8=df8[df8['sepal_length']>average]
df8
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# 115           6.4          3.2           5.3          2.3  virginica
# 116           6.5          3.0           5.5          1.8  virginica
# ...

# %%
df9=df.copy()

df9['area']=df9['petal_length']*df9['petal_width']
df9=df9[df9['area']==df9['area'].max()]
df9=df9.reset_index()
df9['species']
# Out:
# 0    virginica
# Name: species, dtype: object

# %%
df10=df.copy()
df11=df.copy()
df12=df.copy()
df10=df10[df10['species']=='setosa']
df11=df11[df11['species']=='versicolor']
df12=df12[df12['species']=='virginica']
df13=pd.merge(df10,df11, how='outer')
pd.merge(df13,df12,how='outer')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            4.9          3.1           1.5          0.1     setosa
# 11            4.9          3.1           1.5          0.1     setosa
# 12            5.4          3.7           1.5          0.2     setosa
# ...

# %%
#dropped the data in which the sepal width is less than three and petal width more than 0.2
df14=df.copy()
df14=df14[df14['sepal_width']>3]
df14=df14[df14['petal_width']<0.2]
df14
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 9            4.9          3.1           1.5          0.1  setosa
# 32           5.2          4.1           1.5          0.1  setosa
# 34           4.9          3.1           1.5          0.1  setosa
# 37           4.9          3.1           1.5          0.1  setosa
